# %%
# %matplotlib inline
import glob
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
files = glob.glob('results/logistic_regression/*.csv')
plt.figure(figsize=(16,8))
for f in files:
    data = np.loadtxt(f, delimiter=',', skiprows=1)
    plt.subplot(121)
    plt.plot(data[:,1])
    plt.subplot(122)
    plt.plot(data[:,2])
plt.subplot(121)
plt.title('Training Loss')
plt.legend(files)
plt.ylim(ymax=0.32)
plt.subplot(122)
plt.title('Testing Loss')
plt.legend(files)
plt.ylim(ymax=0.50)
plt.savefig('results/logistic_regression.png')

# %%
files = glob.glob('results/cnn/*.csv')
plt.figure(figsize=(16,8))
for f in files:
    data = np.loadtxt(f, delimiter=',', skiprows=1)
    plt.subplot(121)
    plt.plot(data[:,1])
    plt.subplot(122)
    plt.plot(data[:,2])
plt.subplot(121)
plt.title('Training Loss')
plt.legend(files)
plt.ylim(ymax=0.30)
plt.subplot(122)
plt.title('Testing Loss')
plt.legend(files)
plt.ylim(ymax=0.12)
plt.savefig('results/cnn.png')
